# %% [markdown]
# # Unlearn - ResNet50 - Pretrained Model

# %% [markdown]
# * **Author** : Yalla Mahanth
# * **SR No** : 24004

# %% [markdown]
# ## imports

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.optim.lr_scheduler as lr_scheduler
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torchvision.models import alexnet, AlexNet_Weights
from torchvision.models import resnet50, ResNet50_Weights

import os
import tqdm
import math
import json
import pickle
import pynvml
import argparse
import numpy as np

from tqdm import tqdm
import matplotlib.pyplot as plt
from datetime import datetime as dt
import matplotlib.gridspec as gridspec

# %%
VAL_DIR = './data/imagenet-val' 
BATCH_SIZE = 64


def get_best_gpu(verbose = False):
    pynvml.nvmlInit()
    num_gpus = torch.cuda.device_count()

    if num_gpus == 0:
        if verbose :
            print("[!] No CUDA devices found, running on CPU.")
        return 'cpu'

    gpu_mem = []
    for i in range(num_gpus):
        handle = pynvml.nvmlDeviceGetHandleByIndex(i)
        mem_info = pynvml.nvmlDeviceGetMemoryInfo(handle)
        free_mem = mem_info.free
        total_mem = mem_info.total
        if verbose:
            print(f"[+] GPU {i}: Total {total_mem / 1e9:.2f} GB, Free {free_mem / 1e9:.2f} GB")
        gpu_mem.append((i, free_mem))

    gpu_mem.sort(key=lambda x: x[1], reverse=True)

    best_gpu = gpu_mem[0][0]
    second_best_gpu = gpu_mem[1][0] if len(gpu_mem) > 1 else best_gpu

    selected_gpu = second_best_gpu if best_gpu == 0 else best_gpu

    pynvml.nvmlShutdown()
    return selected_gpu

def set_gpu(manual_set = None, verbose = False):
    device_active = 'cuda' if torch.cuda.is_available() else 'cpu'
    if device_active == 'cuda':
        if verbose:
            print('[+] CUDA : available')
        try:
            if manual_set is not None:
                GPU_NUMBER = manual_set
            else:
                GPU_NUMBER = get_best_gpu(verbose)
            if verbose:
                print(f'[>] Current Device {torch.cuda.current_device()} -> changing it to {GPU_NUMBER}')
            torch.cuda.set_device(GPU_NUMBER)
            if verbose:
                print(f'[+] Current Device {torch.cuda.current_device()}')
        except Exception as e:
            if verbose:
                print(f'[-] Error Occured while changing GPU ! \n\n\tERROR :{e}\n\n')
                print(f'[!] CUDA ERR : Couldn\'t change  -> using CPU {device_active = }')
        finally: 
            pass
        print(f'[>] device = cuda:{GPU_NUMBER}')
    else :
        if verbose:
            print(f'[!] CUDA ERR : Not available -> using CPU {device_active = }')
        print(f'[>] device = cpu')

DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406], 
        std=[0.229, 0.224, 0.225]
    )
])

# %%
val_dataset = ImageFolder(root=VAL_DIR, transform=transform)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)

# %% [markdown]
# ### Alex Net - Testing

# %%
# weights = AlexNet_Weights.IMAGENET1K_V1
weights = ResNet50_Weights.IMAGENET1K_V1
# model = alexnet(weights=weights).to(DEVICE)
model = resnet50(weights=weights).to(DEVICE)
model.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
def evaluate_topk(model, dataloader, device, topk=(1, 5)):
    top1_correct = 0
    top5_correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in tqdm(dataloader):
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)

            _, pred_top5 = outputs.topk(max(topk), dim=1, largest=True, sorted=True)

            for i in range(images.size(0)):
                label = labels[i].item()
                top_preds = pred_top5[i]
                if label == top_preds[0].item():
                    top1_correct += 1
                if label in top_preds[:5]:
                    top5_correct += 1
                total += 1

    top1 = 100 * top1_correct / total
    top5 = 100 * top5_correct / total
    return top1, top5

# %%
top1_acc, top5_acc = evaluate_topk(model, val_loader, DEVICE)
print(f"\nTop-1 Accuracy: {top1_acc:.2f}%")
print(f"Top-5 Accuracy: {top5_acc:.2f}%")
# Out:
# 100%|██████████| 782/782 [01:10<00:00, 11.14it/s]
# Top-1 Accuracy: 76.14%
# Top-5 Accuracy: 92.87%

# %% [markdown]
# # ResNet50 - Unlearn

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.optim.lr_scheduler as lr_scheduler
from torch.utils.data import DataLoader, Dataset

import os
import tqdm
import math
import json
import copy 
import pickle
import pynvml
import argparse
import numpy as np

from tqdm import tqdm
import matplotlib.pyplot as plt
from datetime import datetime as dt
import matplotlib.gridspec as gridspec
from collections import defaultdict

# %%
def classwise_accuracy(model, dataloader, device):
    model.eval()
    correct = defaultdict(int)
    total = defaultdict(int)

    with torch.no_grad():
        for images, labels in tqdm(dataloader):
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            preds = outputs.argmax(dim=1)
            for pred, label in zip(preds, labels):
                total[int(label)] += 1
                if pred == label:
                    correct[int(label)] += 1
    return {cls: 100 * correct[cls] / total[cls] for cls in total}

# %%
def record_layer_io_shapes(model, input_shape=(1, 3, 224, 224), device='cuda'):
    io_shapes = {}
    hooks = []

    def make_hook(name):
        def hook(module, input, output):
            io_shapes[name] = {
                'input': tuple(input[0].shape),
                'output': tuple(output.shape)
            }
        return hook

    model.eval().to(device)

    for name, module in model.named_modules():
        if isinstance(module, torch.nn.Module):
            hooks.append(module.register_forward_hook(make_hook(name)))

    dummy_input = torch.randn(*input_shape).to(device)
    with torch.no_grad():
        model(dummy_input)

    for h in hooks:
        h.remove()
    return io_shapes

# %%
def generate_class_impression_from_activation(model, target_class, layer_name, init_mode='kaiming', num_steps=300, lr=0.1, device='cuda', verbose = False):
    model.eval().to(device)

    io_shapes = record_layer_io_shapes(model, device=device)
    if layer_name not in io_shapes:
        raise ValueError(f"Layer '{layer_name}' not found.")

    activation_shape = io_shapes[layer_name]['input']
    if verbose:
        print(f"[+] Shape of activation at input to '{layer_name}': {activation_shape}")

    act_tensor = torch.empty(activation_shape, requires_grad=True, device=device)
    if init_mode == 'kaiming':
        torch.nn.init.kaiming_normal_(act_tensor)
    elif init_mode == 'xavier':
        torch.nn.init.xavier_normal_(act_tensor)
    elif init_mode == 'normal':
        torch.nn.init.normal_(act_tensor, mean=0.0, std=0.02)
    else:
        raise ValueError(f"Unsupported init mode: {init_mode}")

    optimizer = torch.optim.Adam([act_tensor], lr=lr)

    found = False
    tail_layers = []
    for name, module in model.named_modules():
        if name == layer_name:
            found = True
        if found and isinstance(module, torch.nn.Module) and name != '':
            tail_layers.append(module)
    if not tail_layers:
        raise RuntimeError(f"No layers found after {layer_name} to build tail model.")

    tail_net = torch.nn.Sequential(*tail_layers).to(device)


    for step in range(num_steps):
        optimizer.zero_grad()
        output = tail_net(act_tensor)
        target_score = output[0, target_class]
        loss = -target_score
        loss.backward()
        optimizer.step()

        if step % 50 == 0 and verbose:
            print(f"[{step:03d}] Class {target_class} score: {target_score.item():.4f}")

    final_scores = tail_net(act_tensor)
    softmaxes = F.softmax(final_scores, dim=-1)
    max_ele = torch.argmax(softmaxes)
    if verbose :
        print(f'{softmaxes = }\n{max_ele = }')
    
    return act_tensor.detach(), activation_shape , max_ele.item()

# %%
resnet_model = resnet50(weights=ResNet50_Weights.IMAGENET1K_V1)
layer_sizes = record_layer_io_shapes(resnet_model, input_shape=(1, 3, 224, 224))
print(layer_sizes.keys())
# Out:
# dict_keys(['conv1', 'bn1', 'relu', 'maxpool', 'layer1.0.conv1', 'layer1.0.bn1', 'layer1.0.relu', 'layer1.0.conv2', 'layer1.0.bn2', 'layer1.0.conv3', 'layer1.0.bn3', 'layer1.0.downsample.0', 'layer1.0.downsample.1', 'layer1.0.downsample', 'layer1.0', 'layer1.1.conv1', 'layer1.1.bn1', 'layer1.1.relu', 'layer1.1.conv2', 'layer1.1.bn2', 'layer1.1.conv3', 'layer1.1.bn3', 'layer1.1', 'layer1.2.conv1', 'layer1.2.bn1', 'layer1.2.relu', 'layer1.2.conv2', 'layer1.2.bn2', 'layer1.2.conv3', 'layer1.2.bn3', 'layer1.2', 'layer1', 'layer2.0.conv1', 'layer2.0.bn1', 'layer2.0.relu', 'layer2.0.conv2', 'layer2.0.bn2', 'layer2.0.conv3', 'layer2.0.bn3', 'layer2.0.downsample.0', 'layer2.0.downsample.1', 'layer2.0.downsample', 'layer2.0', 'layer2.1.conv1', 'layer2.1.bn1', 'layer2.1.relu', 'layer2.1.conv2', 'layer2.1.bn2', 'layer2.1.conv3', 'layer2.1.bn3', 'layer2.1', 'layer2.2.conv1', 'layer2.2.bn1', 'layer2.2.relu', 'layer2.2.conv2', 'layer2.2.bn2', 'layer2.2.conv3', 'layer2.2.bn3', 'layer2.2', 'layer2.3.conv1', 'layer2.3.bn1', 'layer2.3.relu', 'layer2.3.conv2', 'layer2.3.bn2', 'layer2.3.conv3', 'layer2.3.bn3', 'layer2.3', 'layer2', 'layer3.0.conv1', 'layer3.0.bn1', 'layer3.0.relu', 'layer3.0.conv2', 'layer3.0.bn2', 'layer3.0.conv3', 'layer3.0.bn3', 'layer3.0.downsample.0', 'layer3.0.downsample.1', 'layer3.0.downsample', 'layer3.0', 'layer3.1.conv1', 'layer3.1.bn1', 'layer3.1.relu', 'layer3.1.conv2', 'layer3.1.bn2', 'layer3.1.conv3', 'layer3.1.bn3', 'layer3.1', 'layer3.2.conv1', 'layer3.2.bn1', 'layer3.2.relu', 'layer3.2.conv2', 'layer3.2.bn2', 'layer3.2.conv3', 'layer3.2.bn3', 'layer3.2', 'layer3.3.conv1', 'layer3.3.bn1', 'layer3.3.relu', 'layer3.3.conv2', 'layer3.3.bn2', 'layer3.3.conv3', 'layer3.3.bn3', 'layer3.3', 'layer3.4.conv1', 'layer3.4.bn1', 'layer3.4.relu', 'layer3.4.conv2', 'layer3.4.bn2', 'layer3.4.conv3', 'layer3.4.bn3', 'layer3.4', 'layer3.5.conv1', 'layer3.5.bn1', 'layer3.5.relu', 'layer3.5.conv2', 'layer3.5.bn2', 'layer3.5.conv3', 'layer3.5.bn3', 'layer3.5', 'layer3', 'layer4.0.conv1', 'layer4.0.bn1', 'layer4.0.relu', 'layer4.0.conv2', 'layer4.0.bn2', 'layer4.0.conv3', 'layer4.0.bn3', 'layer4.0.downsample.0', 'layer4.0.downsample.1', 'layer4.0.downsample', 'layer4.0', 'layer4.1.conv1', 'layer4.1.bn1', 'layer4.1.relu', 'layer4.1.conv2', 'layer4.1.bn2', 'layer4.1.conv3', 'layer4.1.bn3', 'layer4.1', 'layer4.2.conv1', 'layer4.2.bn1', 'layer4.2.relu', 'layer4.2.conv2', 'layer4.2.bn2', 'layer4.2.conv3', 'layer4.2.bn3', 'layer4.2', 'layer4', 'avgpool', 'fc', ''])

# %%
def get_learnable_layers(model, responsive_layers):
    learnable_layers = []
    for layer_name in responsive_layers:
        has_params = False
        for name, param in model.named_parameters():
            if layer_name in name and param.requires_grad and param.numel() > 0:
                has_params = True
                break
        if has_params:
            learnable_layers.append(layer_name)
        else:
            print(f"[⏭] Skipping non-learnable layer: {layer_name}")
    
    return learnable_layers

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_accuracy_diff(acc_before, acc_after, class_idx_to_name):
    classes = sorted(acc_before.keys())
    diffs = [acc_after.get(cls, 0) - acc_before.get(cls, 0) for cls in classes]

    colors = ['green' if d >= 0 else 'red' for d in diffs]
    names = [class_idx_to_name.get(cls, str(cls)) for cls in classes]

    plt.figure(figsize=(20, 6))
    bars = plt.bar(range(len(classes)), diffs, color=colors)
    plt.axhline(0, color='black', linewidth=0.8)
    plt.title("Change in Class-wise Accuracy After Unlearning")
    plt.xlabel("Class")
    plt.ylabel("Accuracy Change (%)")
    plt.xticks(range(len(classes)), names, rotation=90)
    plt.tight_layout()
    plt.show()

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
acc_before = classwise_accuracy(model, val_loader, device)
# Out:
# 100%|██████████| 782/782 [01:08<00:00, 11.44it/s]

# %%
class ImpressionDataset(Dataset):
    def __init__(self, data_tensor):
        self.data = data_tensor
    def __len__(self):
        return self.data.shape[0]
    def __getitem__(self, idx):
        return self.data[idx]

# %%
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
layer_names = list(layer_sizes.keys())[:-1]
layer_names
# Out:
# ['conv1',
#  'bn1',
#  'relu',
#  'maxpool',
#  'layer1.0.conv1',
#  'layer1.0.bn1',
#  'layer1.0.relu',
#  'layer1.0.conv2',
#  'layer1.0.bn2',
#  'layer1.0.conv3',
#  'layer1.0.bn3',
#  'layer1.0.downsample.0',
#  'layer1.0.downsample.1',
#  'layer1.0.downsample',
#  'layer1.0',
#  'layer1.1.conv1',
#  'layer1.1.bn1',
#  'layer1.1.relu',
#  'layer1.1.conv2',
#  'layer1.1.bn2',
#  'layer1.1.conv3',
#  'layer1.1.bn3',
#  'layer1.1',
#  'layer1.2.conv1',
#  'layer1.2.bn1',
#  'layer1.2.relu',
#  'layer1.2.conv2',
#  'layer1.2.bn2',
#  'layer1.2.conv3',
#  'layer1.2.bn3',
#  'layer1.2',
#  'layer1',
#  'layer2.0.conv1',
#  'layer2.0.bn1',
#  'layer2.0.relu',
#  'layer2.0.conv2',
#  'layer2.0.bn2',
#  'layer2.0.conv3',
#  'layer2.0.bn3',
#  'layer2.0.downsample.0',
#  'layer2.0.downsample.1',
#  'layer2.0.downsample',
#  'layer2.0',
#  'layer2.1.conv1',
#  'layer2.1.bn1',
#  'layer2.1.relu',
#  'layer2.1.conv2',
#  'layer2.1.bn2',
#  'layer2.1.conv3',
#  'layer2.1.bn3',
#  'layer2.1',
#  'layer2.2.conv1',
#  'layer2.2.bn1',
#  'layer2.2.relu',
#  'layer2.2.conv2',
#  'layer2.2.bn2',
#  'layer2.2.conv3',
#  'layer2.2.bn3',
#  'layer2.2',
#  'layer2.3.conv1',
#  'layer2.3.bn1',
#  'layer2.3.relu',
#  'layer2.3.conv2',
#  'layer2.3.bn2',
#  'layer2.3.conv3',
#  'layer2.3.bn3',
#  'layer2.3',
#  'layer2',
#  'layer3.0.conv1',
#  'layer3.0.bn1',
#  'layer3.0.relu',
#  'layer3.0.conv2',
#  'layer3.0.bn2',
#  'layer3.0.conv3',
#  'layer3.0.bn3',
#  'layer3.0.downsample.0',
#  'layer3.0.downsample.1',
#  'layer3.0.downsample',
#  'layer3.0',
#  'layer3.1.conv1',
#  'layer3.1.bn1',
#  'layer3.1.relu',
#  'layer3.1.conv2',
#  'layer3.1.bn2',
#  'layer3.1.conv3',
#  'layer3.1.bn3',
#  'layer3.1',
#  'layer3.2.conv1',
#  'layer3.2.bn1',
#  'layer3.2.relu',
#  'layer3.2.conv2',
#  'layer3.2.bn2',
#  'layer3.2.conv3',
#  'layer3.2.bn3',
#  'layer3.2',
#  'layer3.3.conv1',
#  'layer3.3.bn1',
#  'layer3.3.relu',
#  'layer3.3.conv2',
#  'layer3.3.bn2',
#  'layer3.3.conv3',
#  'layer3.3.bn3',
#  'layer3.3',
#  'layer3.4.conv1',
#  'layer3.4.bn1',
#  'layer3.4.relu',
#  'layer3.4.conv2',
#  'layer3.4.bn2',
#  'layer3.4.conv3',
#  'layer3.4.bn3',
#  'layer3.4',
#  'layer3.5.conv1',
#  'layer3.5.bn1',
#  'layer3.5.relu',
#  'layer3.5.conv2',
#  'layer3.5.bn2',
#  'layer3.5.conv3',
#  'layer3.5.bn3',
#  'layer3.5',
#  'layer3',
#  'layer4.0.conv1',
#  'layer4.0.bn1',
#  'layer4.0.relu',
#  'layer4.0.conv2',
#  'layer4.0.bn2',
#  'layer4.0.conv3',
#  'layer4.0.bn3',
#  'layer4.0.downsample.0',
#  'layer4.0.downsample.1',
#  'layer4.0.downsample',
#  'layer4.0',
#  'layer4.1.conv1',
#  'layer4.1.bn1',
#  'layer4.1.relu',
#  'layer4.1.conv2',
#  'layer4.1.bn2',
#  'layer4.1.conv3',
#  'layer4.1.bn3',
#  'layer4.1',
#  'layer4.2.conv1',
#  'layer4.2.bn1',
#  'layer4.2.relu',
#  'layer4.2.conv2',
#  'layer4.2.bn2',
#  'layer4.2.conv3',
#  'layer4.2.bn3',
#  'layer4.2',
#  'layer4',
#  'avgpool',
#  'fc']

# %%
# target_class = 44
# n_attempts = 5
# threshold = 0.75
# first_responsive_layer = None

# all_responses = {}
# responsive_layers = []
# for layer in layer_names:
#     correct = 0
#     for _ in range(n_attempts):
#         _, _, max_ele = generate_class_impression_from_activation(model, target_class, layer)
#         if max_ele == target_class:
#             correct += 1
#     if correct >= threshold:
#         if first_responsive_layer is None:
#             first_responsive_layer = layer
#         responsive_layers.append(layer)
        
#     all_responses[layer] = correct

# all_responses, responsive_layers, first_responsive_layer

# %%
# learnable_layers = get_learnable_layers(model, responsive_layers)
# learnable_layers

# %%
first_responsive_layer = 'fc'

# %%
model_name = 'ResNet50'
model_version = 'pretrained'
directory = f'./models/{model_name}_{model_version}/'
if not os.path.exists(directory):
    os.makedirs(directory)

# %%
os.makedirs(f'{directory}/class_impressions/',exist_ok=True)

# %%
def generate_class_impression_dataset(model, target_class, layer_name,  num_samples=500, init_mode='kaiming', num_steps=300, lr=0.1, device='cuda'):
    all_activations = []
    eps = 1e-9
    while len(all_activations) < num_samples:
        impression, shape, max_ele = generate_class_impression_from_activation(model, target_class=target_class, layer_name=layer_name, init_mode=init_mode, num_steps=num_steps, lr=lr, device = device)
        if max_ele == target_class:
            for s in all_activations:
                if torch.norm(s - impression) < eps:
                    break
            else:
                all_activations.append(impression)

    stacked_tensor = torch.cat(all_activations, dim=0)
    save_path = f'{directory}/class_impressions/{layer_name}_class_{target_class}_{num_samples}.pt'
    torch.save(stacked_tensor, save_path)
    
    return save_path

def generate_class_impression(model, target_class, layer_name, directory,  num_samples=500, init_mode='kaiming', num_steps=300, lr=0.1, device='cuda'):
    save_path = f'{directory}/class_impressions/{layer_name}_class_{target_class}_{num_samples}.pt'
    if os.path.exists(save_path):
        print(f"[!] Class impression dataset for class {target_class} and layer {layer_name} already exists.")
        return save_path
    all_activations = []
    eps = 1e-9
    while len(all_activations) < num_samples:
        impression, shape, max_ele = generate_class_impression_from_activation(model, target_class=target_class, layer_name=layer_name, init_mode=init_mode, num_steps=num_steps, lr=lr, device = device)
        if max_ele == target_class:
            for s in all_activations:
                if torch.norm(s - impression) < eps:
                    break
            else:
                all_activations.append(impression)

    stacked_tensor = torch.cat(all_activations, dim=0)
    torch.save(stacked_tensor, save_path)
    
    return save_path

def generate_cis_for_all_classes(labels, model, layer_name, directory, num_samples=500, init_mode='kaiming', num_steps=300, lr=0.1, device='cuda'):
    paths = {}
    for cls in list(labels):    
        paths[cls] = generate_class_impression(
            model=model,
            target_class=cls,
            layer_name=layer_name,
            directory=directory,
            num_samples=num_samples,
            init_mode=init_mode,
            num_steps=num_steps,
            lr=lr,
            device=device 
        )
        print(f'[+] {cls = } {paths[cls] = }')
    return paths

# %%
labels = np.arange(1000)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
TARGET_CLS = 7

net_name = 'ResNet50'
version_name = 'pretrained'
directory = f'./models/{net_name}_{version_name}'

ci_dir = f'{directory}/class_impressions'
os.makedirs(ci_dir, exist_ok=True)

# %%
NUM_SAMPLES = 25
LAYER_NAME = first_responsive_layer
INIT_MODE = 'xavier'
STEPS_PER_SAMPLE = 250
LEARN_RATE = 0.1

paths_cis = generate_cis_for_all_classes(
    labels = labels,
    model  = model,
    directory = directory,
    layer_name=LAYER_NAME,
    num_samples=NUM_SAMPLES,
    init_mode=INIT_MODE,
    num_steps=STEPS_PER_SAMPLE,
    lr=LEARN_RATE,
    device=device ,
)
print(paths_cis)
# Out:
# [+] cls = np.int64(0) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_0_25.pt'
# [+] cls = np.int64(1) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_1_25.pt'
# [+] cls = np.int64(2) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_2_25.pt'
# [+] cls = np.int64(3) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_3_25.pt'
# [+] cls = np.int64(4) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_4_25.pt'
# [+] cls = np.int64(5) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_5_25.pt'
# [+] cls = np.int64(6) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_6_25.pt'
# [+] cls = np.int64(7) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_7_25.pt'
# [+] cls = np.int64(8) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_8_25.pt'
# [+] cls = np.int64(9) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_9_25.pt'
# [+] cls = np.int64(10) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_10_25.pt'
# [+] cls = np.int64(11) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_11_25.pt'
# [+] cls = np.int64(12) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_12_25.pt'
# [+] cls = np.int64(13) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_13_25.pt'
# [+] cls = np.int64(14) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_14_25.pt'
# [+] cls = np.int64(15) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_15_25.pt'
# [+] cls = np.int64(16) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_16_25.pt'
# [+] cls = np.int64(17) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_17_25.pt'
# [+] cls = np.int64(18) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_18_25.pt'
# [+] cls = np.int64(19) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_19_25.pt'
# [+] cls = np.int64(20) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_20_25.pt'
# [+] cls = np.int64(21) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_21_25.pt'
# [+] cls = np.int64(22) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_22_25.pt'
# [+] cls = np.int64(23) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_23_25.pt'
# [+] cls = np.int64(24) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_24_25.pt'
# [+] cls = np.int64(25) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_25_25.pt'
# [+] cls = np.int64(26) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_26_25.pt'
# [+] cls = np.int64(27) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_27_25.pt'
# [+] cls = np.int64(28) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_28_25.pt'
# [+] cls = np.int64(29) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_29_25.pt'
# [+] cls = np.int64(30) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_30_25.pt'
# [+] cls = np.int64(31) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_31_25.pt'
# [+] cls = np.int64(32) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_32_25.pt'
# [+] cls = np.int64(33) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_33_25.pt'
# [+] cls = np.int64(34) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_34_25.pt'
# [+] cls = np.int64(35) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_35_25.pt'
# [+] cls = np.int64(36) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_36_25.pt'
# [+] cls = np.int64(37) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_37_25.pt'
# [+] cls = np.int64(38) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_38_25.pt'
# [+] cls = np.int64(39) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_39_25.pt'
# [+] cls = np.int64(40) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_40_25.pt'
# [+] cls = np.int64(41) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_41_25.pt'
# [+] cls = np.int64(42) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_42_25.pt'
# [+] cls = np.int64(43) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_43_25.pt'
# [+] cls = np.int64(44) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_44_25.pt'
# [+] cls = np.int64(45) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_45_25.pt'
# [+] cls = np.int64(46) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_46_25.pt'
# [+] cls = np.int64(47) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_47_25.pt'
# [+] cls = np.int64(48) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_48_25.pt'
# [+] cls = np.int64(49) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_49_25.pt'
# [+] cls = np.int64(50) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_50_25.pt'
# [+] cls = np.int64(51) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_51_25.pt'
# [+] cls = np.int64(52) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_52_25.pt'
# [+] cls = np.int64(53) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_53_25.pt'
# [+] cls = np.int64(54) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_54_25.pt'
# [+] cls = np.int64(55) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_55_25.pt'
# [+] cls = np.int64(56) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_56_25.pt'
# [+] cls = np.int64(57) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_57_25.pt'
# [+] cls = np.int64(58) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_58_25.pt'
# [+] cls = np.int64(59) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_59_25.pt'
# [+] cls = np.int64(60) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_60_25.pt'
# [+] cls = np.int64(61) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_61_25.pt'
# [+] cls = np.int64(62) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_62_25.pt'
# [+] cls = np.int64(63) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_63_25.pt'
# [+] cls = np.int64(64) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_64_25.pt'
# [+] cls = np.int64(65) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_65_25.pt'
# [+] cls = np.int64(66) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_66_25.pt'
# [+] cls = np.int64(67) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_67_25.pt'
# [+] cls = np.int64(68) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_68_25.pt'
# [+] cls = np.int64(69) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_69_25.pt'
# [+] cls = np.int64(70) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_70_25.pt'
# [+] cls = np.int64(71) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_71_25.pt'
# [+] cls = np.int64(72) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_72_25.pt'
# [+] cls = np.int64(73) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_73_25.pt'
# [+] cls = np.int64(74) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_74_25.pt'
# [+] cls = np.int64(75) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_75_25.pt'
# [+] cls = np.int64(76) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_76_25.pt'
# [+] cls = np.int64(77) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_77_25.pt'
# [+] cls = np.int64(78) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_78_25.pt'
# [+] cls = np.int64(79) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_79_25.pt'
# [+] cls = np.int64(80) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_80_25.pt'
# [+] cls = np.int64(81) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_81_25.pt'
# [+] cls = np.int64(82) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_82_25.pt'
# [+] cls = np.int64(83) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_83_25.pt'
# [+] cls = np.int64(84) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_84_25.pt'
# [+] cls = np.int64(85) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_85_25.pt'
# [+] cls = np.int64(86) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_86_25.pt'
# [+] cls = np.int64(87) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_87_25.pt'
# [+] cls = np.int64(88) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_88_25.pt'
# [+] cls = np.int64(89) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_89_25.pt'
# [+] cls = np.int64(90) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_90_25.pt'
# [+] cls = np.int64(91) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_91_25.pt'
# [+] cls = np.int64(92) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_92_25.pt'
# [+] cls = np.int64(93) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_93_25.pt'
# [+] cls = np.int64(94) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_94_25.pt'
# [+] cls = np.int64(95) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_95_25.pt'
# [+] cls = np.int64(96) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_96_25.pt'
# [+] cls = np.int64(97) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_97_25.pt'
# [+] cls = np.int64(98) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_98_25.pt'
# [+] cls = np.int64(99) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_99_25.pt'
# [+] cls = np.int64(100) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_100_25.pt'
# [+] cls = np.int64(101) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_101_25.pt'
# [+] cls = np.int64(102) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_102_25.pt'
# [+] cls = np.int64(103) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_103_25.pt'
# [+] cls = np.int64(104) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_104_25.pt'
# [+] cls = np.int64(105) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_105_25.pt'
# [+] cls = np.int64(106) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_106_25.pt'
# [+] cls = np.int64(107) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_107_25.pt'
# [+] cls = np.int64(108) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_108_25.pt'
# [+] cls = np.int64(109) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_109_25.pt'
# [+] cls = np.int64(110) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_110_25.pt'
# [+] cls = np.int64(111) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_111_25.pt'
# [+] cls = np.int64(112) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_112_25.pt'
# [+] cls = np.int64(113) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_113_25.pt'
# [+] cls = np.int64(114) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_114_25.pt'
# [+] cls = np.int64(115) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_115_25.pt'
# [+] cls = np.int64(116) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_116_25.pt'
# [+] cls = np.int64(117) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_117_25.pt'
# [+] cls = np.int64(118) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_118_25.pt'
# [+] cls = np.int64(119) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_119_25.pt'
# [+] cls = np.int64(120) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_120_25.pt'
# [+] cls = np.int64(121) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_121_25.pt'
# [+] cls = np.int64(122) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_122_25.pt'
# [+] cls = np.int64(123) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_123_25.pt'
# [+] cls = np.int64(124) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_124_25.pt'
# [+] cls = np.int64(125) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_125_25.pt'
# [+] cls = np.int64(126) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_126_25.pt'
# [+] cls = np.int64(127) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_127_25.pt'
# [+] cls = np.int64(128) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_128_25.pt'
# [+] cls = np.int64(129) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_129_25.pt'
# [+] cls = np.int64(130) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_130_25.pt'
# [+] cls = np.int64(131) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_131_25.pt'
# [+] cls = np.int64(132) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_132_25.pt'
# [+] cls = np.int64(133) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_133_25.pt'
# [+] cls = np.int64(134) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_134_25.pt'
# [+] cls = np.int64(135) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_135_25.pt'
# [+] cls = np.int64(136) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_136_25.pt'
# [+] cls = np.int64(137) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_137_25.pt'
# [+] cls = np.int64(138) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_138_25.pt'
# [+] cls = np.int64(139) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_139_25.pt'
# [+] cls = np.int64(140) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_140_25.pt'
# [+] cls = np.int64(141) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_141_25.pt'
# [+] cls = np.int64(142) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_142_25.pt'
# [+] cls = np.int64(143) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_143_25.pt'
# [+] cls = np.int64(144) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_144_25.pt'
# [+] cls = np.int64(145) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_145_25.pt'
# [+] cls = np.int64(146) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_146_25.pt'
# [+] cls = np.int64(147) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_147_25.pt'
# [+] cls = np.int64(148) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_148_25.pt'
# [+] cls = np.int64(149) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_149_25.pt'
# [+] cls = np.int64(150) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_150_25.pt'
# [+] cls = np.int64(151) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_151_25.pt'
# [+] cls = np.int64(152) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_152_25.pt'
# [+] cls = np.int64(153) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_153_25.pt'
# [+] cls = np.int64(154) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_154_25.pt'
# [+] cls = np.int64(155) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_155_25.pt'
# [+] cls = np.int64(156) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_156_25.pt'
# [+] cls = np.int64(157) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_157_25.pt'
# [+] cls = np.int64(158) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_158_25.pt'
# [+] cls = np.int64(159) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_159_25.pt'
# [+] cls = np.int64(160) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_160_25.pt'
# [+] cls = np.int64(161) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_161_25.pt'
# [+] cls = np.int64(162) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_162_25.pt'
# [+] cls = np.int64(163) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_163_25.pt'
# [+] cls = np.int64(164) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_164_25.pt'
# [+] cls = np.int64(165) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_165_25.pt'
# [+] cls = np.int64(166) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_166_25.pt'
# [+] cls = np.int64(167) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_167_25.pt'
# [+] cls = np.int64(168) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_168_25.pt'
# [+] cls = np.int64(169) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_169_25.pt'
# [+] cls = np.int64(170) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_170_25.pt'
# [+] cls = np.int64(171) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_171_25.pt'
# [+] cls = np.int64(172) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_172_25.pt'
# [+] cls = np.int64(173) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_173_25.pt'
# [+] cls = np.int64(174) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_174_25.pt'
# [+] cls = np.int64(175) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_175_25.pt'
# [+] cls = np.int64(176) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_176_25.pt'
# [+] cls = np.int64(177) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_177_25.pt'
# [+] cls = np.int64(178) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_178_25.pt'
# [+] cls = np.int64(179) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_179_25.pt'
# [+] cls = np.int64(180) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_180_25.pt'
# [+] cls = np.int64(181) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_181_25.pt'
# [+] cls = np.int64(182) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_182_25.pt'
# [+] cls = np.int64(183) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_183_25.pt'
# [+] cls = np.int64(184) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_184_25.pt'
# [+] cls = np.int64(185) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_185_25.pt'
# [+] cls = np.int64(186) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_186_25.pt'
# [+] cls = np.int64(187) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_187_25.pt'
# [+] cls = np.int64(188) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_188_25.pt'
# [+] cls = np.int64(189) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_189_25.pt'
# [+] cls = np.int64(190) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_190_25.pt'
# [+] cls = np.int64(191) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_191_25.pt'
# [+] cls = np.int64(192) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_192_25.pt'
# [+] cls = np.int64(193) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_193_25.pt'
# [+] cls = np.int64(194) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_194_25.pt'
# [+] cls = np.int64(195) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_195_25.pt'
# [+] cls = np.int64(196) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_196_25.pt'
# [+] cls = np.int64(197) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_197_25.pt'
# [+] cls = np.int64(198) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_198_25.pt'
# [+] cls = np.int64(199) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_199_25.pt'
# [+] cls = np.int64(200) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_200_25.pt'
# [+] cls = np.int64(201) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_201_25.pt'
# [+] cls = np.int64(202) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_202_25.pt'
# [+] cls = np.int64(203) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_203_25.pt'
# [+] cls = np.int64(204) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_204_25.pt'
# [+] cls = np.int64(205) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_205_25.pt'
# [+] cls = np.int64(206) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_206_25.pt'
# [+] cls = np.int64(207) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_207_25.pt'
# [+] cls = np.int64(208) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_208_25.pt'
# [+] cls = np.int64(209) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_209_25.pt'
# [+] cls = np.int64(210) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_210_25.pt'
# [+] cls = np.int64(211) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_211_25.pt'
# [+] cls = np.int64(212) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_212_25.pt'
# [+] cls = np.int64(213) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_213_25.pt'
# [+] cls = np.int64(214) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_214_25.pt'
# [+] cls = np.int64(215) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_215_25.pt'
# [+] cls = np.int64(216) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_216_25.pt'
# [+] cls = np.int64(217) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_217_25.pt'
# [+] cls = np.int64(218) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_218_25.pt'
# [+] cls = np.int64(219) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_219_25.pt'
# [+] cls = np.int64(220) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_220_25.pt'
# [+] cls = np.int64(221) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_221_25.pt'
# [+] cls = np.int64(222) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_222_25.pt'
# [+] cls = np.int64(223) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_223_25.pt'
# [+] cls = np.int64(224) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_224_25.pt'
# [+] cls = np.int64(225) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_225_25.pt'
# [+] cls = np.int64(226) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_226_25.pt'
# [+] cls = np.int64(227) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_227_25.pt'
# [+] cls = np.int64(228) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_228_25.pt'
# [+] cls = np.int64(229) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_229_25.pt'
# [+] cls = np.int64(230) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_230_25.pt'
# [+] cls = np.int64(231) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_231_25.pt'
# [+] cls = np.int64(232) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_232_25.pt'
# [+] cls = np.int64(233) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_233_25.pt'
# [+] cls = np.int64(234) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_234_25.pt'
# [+] cls = np.int64(235) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_235_25.pt'
# [+] cls = np.int64(236) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_236_25.pt'
# [+] cls = np.int64(237) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_237_25.pt'
# [+] cls = np.int64(238) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_238_25.pt'
# [+] cls = np.int64(239) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_239_25.pt'
# [+] cls = np.int64(240) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_240_25.pt'
# [+] cls = np.int64(241) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_241_25.pt'
# [+] cls = np.int64(242) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_242_25.pt'
# [+] cls = np.int64(243) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_243_25.pt'
# [+] cls = np.int64(244) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_244_25.pt'
# [+] cls = np.int64(245) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_245_25.pt'
# [+] cls = np.int64(246) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_246_25.pt'
# [+] cls = np.int64(247) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_247_25.pt'
# [+] cls = np.int64(248) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_248_25.pt'
# [+] cls = np.int64(249) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_249_25.pt'
# [+] cls = np.int64(250) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_250_25.pt'
# [+] cls = np.int64(251) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_251_25.pt'
# [+] cls = np.int64(252) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_252_25.pt'
# [+] cls = np.int64(253) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_253_25.pt'
# [+] cls = np.int64(254) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_254_25.pt'
# [+] cls = np.int64(255) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_255_25.pt'
# [+] cls = np.int64(256) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_256_25.pt'
# [+] cls = np.int64(257) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_257_25.pt'
# [+] cls = np.int64(258) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_258_25.pt'
# [+] cls = np.int64(259) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_259_25.pt'
# [+] cls = np.int64(260) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_260_25.pt'
# [+] cls = np.int64(261) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_261_25.pt'
# [+] cls = np.int64(262) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_262_25.pt'
# [+] cls = np.int64(263) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_263_25.pt'
# [+] cls = np.int64(264) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_264_25.pt'
# [+] cls = np.int64(265) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_265_25.pt'
# [+] cls = np.int64(266) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_266_25.pt'
# [+] cls = np.int64(267) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_267_25.pt'
# [+] cls = np.int64(268) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_268_25.pt'
# [+] cls = np.int64(269) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_269_25.pt'
# [+] cls = np.int64(270) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_270_25.pt'
# [+] cls = np.int64(271) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_271_25.pt'
# [+] cls = np.int64(272) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_272_25.pt'
# [+] cls = np.int64(273) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_273_25.pt'
# [+] cls = np.int64(274) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_274_25.pt'
# [+] cls = np.int64(275) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_275_25.pt'
# [+] cls = np.int64(276) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_276_25.pt'
# [+] cls = np.int64(277) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_277_25.pt'
# [+] cls = np.int64(278) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_278_25.pt'
# [+] cls = np.int64(279) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_279_25.pt'
# [+] cls = np.int64(280) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_280_25.pt'
# [+] cls = np.int64(281) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_281_25.pt'
# [+] cls = np.int64(282) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_282_25.pt'
# [+] cls = np.int64(283) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_283_25.pt'
# [+] cls = np.int64(284) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_284_25.pt'
# [+] cls = np.int64(285) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_285_25.pt'
# [+] cls = np.int64(286) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_286_25.pt'
# [+] cls = np.int64(287) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_287_25.pt'
# [+] cls = np.int64(288) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_288_25.pt'
# [+] cls = np.int64(289) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_289_25.pt'
# [+] cls = np.int64(290) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_290_25.pt'
# [+] cls = np.int64(291) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_291_25.pt'
# [+] cls = np.int64(292) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_292_25.pt'
# [+] cls = np.int64(293) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_293_25.pt'
# [+] cls = np.int64(294) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_294_25.pt'
# [+] cls = np.int64(295) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_295_25.pt'
# [+] cls = np.int64(296) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_296_25.pt'
# [+] cls = np.int64(297) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_297_25.pt'
# [+] cls = np.int64(298) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_298_25.pt'
# [+] cls = np.int64(299) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_299_25.pt'
# [+] cls = np.int64(300) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_300_25.pt'
# [+] cls = np.int64(301) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_301_25.pt'
# [+] cls = np.int64(302) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_302_25.pt'
# [+] cls = np.int64(303) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_303_25.pt'
# [+] cls = np.int64(304) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_304_25.pt'
# [+] cls = np.int64(305) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_305_25.pt'
# [+] cls = np.int64(306) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_306_25.pt'
# [+] cls = np.int64(307) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_307_25.pt'
# [+] cls = np.int64(308) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_308_25.pt'
# [+] cls = np.int64(309) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_309_25.pt'
# [+] cls = np.int64(310) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_310_25.pt'
# [+] cls = np.int64(311) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_311_25.pt'
# [+] cls = np.int64(312) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_312_25.pt'
# [+] cls = np.int64(313) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_313_25.pt'
# [+] cls = np.int64(314) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_314_25.pt'
# [+] cls = np.int64(315) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_315_25.pt'
# [+] cls = np.int64(316) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_316_25.pt'
# [+] cls = np.int64(317) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_317_25.pt'
# [+] cls = np.int64(318) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_318_25.pt'
# [+] cls = np.int64(319) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_319_25.pt'
# [+] cls = np.int64(320) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_320_25.pt'
# [+] cls = np.int64(321) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_321_25.pt'
# [+] cls = np.int64(322) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_322_25.pt'
# [+] cls = np.int64(323) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_323_25.pt'
# [+] cls = np.int64(324) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_324_25.pt'
# [+] cls = np.int64(325) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_325_25.pt'
# [+] cls = np.int64(326) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_326_25.pt'
# [+] cls = np.int64(327) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_327_25.pt'
# [+] cls = np.int64(328) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_328_25.pt'
# [+] cls = np.int64(329) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_329_25.pt'
# [+] cls = np.int64(330) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_330_25.pt'
# [+] cls = np.int64(331) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_331_25.pt'
# [+] cls = np.int64(332) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_332_25.pt'
# [+] cls = np.int64(333) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_333_25.pt'
# [+] cls = np.int64(334) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_334_25.pt'
# [+] cls = np.int64(335) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_335_25.pt'
# [+] cls = np.int64(336) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_336_25.pt'
# [+] cls = np.int64(337) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_337_25.pt'
# [+] cls = np.int64(338) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_338_25.pt'
# [+] cls = np.int64(339) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_339_25.pt'
# [+] cls = np.int64(340) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_340_25.pt'
# [+] cls = np.int64(341) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_341_25.pt'
# [+] cls = np.int64(342) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_342_25.pt'
# [+] cls = np.int64(343) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_343_25.pt'
# [+] cls = np.int64(344) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_344_25.pt'
# [+] cls = np.int64(345) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_345_25.pt'
# [+] cls = np.int64(346) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_346_25.pt'
# [+] cls = np.int64(347) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_347_25.pt'
# [+] cls = np.int64(348) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_348_25.pt'
# [+] cls = np.int64(349) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_349_25.pt'
# [+] cls = np.int64(350) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_350_25.pt'
# [+] cls = np.int64(351) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_351_25.pt'
# [+] cls = np.int64(352) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_352_25.pt'
# [+] cls = np.int64(353) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_353_25.pt'
# [+] cls = np.int64(354) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_354_25.pt'
# [+] cls = np.int64(355) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_355_25.pt'
# [+] cls = np.int64(356) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_356_25.pt'
# [+] cls = np.int64(357) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_357_25.pt'
# [+] cls = np.int64(358) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_358_25.pt'
# [+] cls = np.int64(359) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_359_25.pt'
# [+] cls = np.int64(360) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_360_25.pt'
# [+] cls = np.int64(361) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_361_25.pt'
# [+] cls = np.int64(362) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_362_25.pt'
# [+] cls = np.int64(363) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_363_25.pt'
# [+] cls = np.int64(364) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_364_25.pt'
# [+] cls = np.int64(365) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_365_25.pt'
# [+] cls = np.int64(366) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_366_25.pt'
# [+] cls = np.int64(367) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_367_25.pt'
# [+] cls = np.int64(368) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_368_25.pt'
# [+] cls = np.int64(369) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_369_25.pt'
# [+] cls = np.int64(370) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_370_25.pt'
# [+] cls = np.int64(371) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_371_25.pt'
# [+] cls = np.int64(372) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_372_25.pt'
# [+] cls = np.int64(373) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_373_25.pt'
# [+] cls = np.int64(374) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_374_25.pt'
# [+] cls = np.int64(375) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_375_25.pt'
# [+] cls = np.int64(376) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_376_25.pt'
# [+] cls = np.int64(377) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_377_25.pt'
# [+] cls = np.int64(378) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_378_25.pt'
# [+] cls = np.int64(379) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_379_25.pt'
# [+] cls = np.int64(380) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_380_25.pt'
# [+] cls = np.int64(381) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_381_25.pt'
# [+] cls = np.int64(382) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_382_25.pt'
# [+] cls = np.int64(383) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_383_25.pt'
# [+] cls = np.int64(384) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_384_25.pt'
# [+] cls = np.int64(385) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_385_25.pt'
# [+] cls = np.int64(386) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_386_25.pt'
# [+] cls = np.int64(387) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_387_25.pt'
# [+] cls = np.int64(388) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_388_25.pt'
# [+] cls = np.int64(389) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_389_25.pt'
# [+] cls = np.int64(390) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_390_25.pt'
# [+] cls = np.int64(391) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_391_25.pt'
# [+] cls = np.int64(392) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_392_25.pt'
# [+] cls = np.int64(393) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_393_25.pt'
# [+] cls = np.int64(394) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_394_25.pt'
# [+] cls = np.int64(395) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_395_25.pt'
# [+] cls = np.int64(396) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_396_25.pt'
# [+] cls = np.int64(397) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_397_25.pt'
# [+] cls = np.int64(398) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_398_25.pt'
# [+] cls = np.int64(399) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_399_25.pt'
# [+] cls = np.int64(400) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_400_25.pt'
# [+] cls = np.int64(401) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_401_25.pt'
# [+] cls = np.int64(402) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_402_25.pt'
# [+] cls = np.int64(403) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_403_25.pt'
# [+] cls = np.int64(404) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_404_25.pt'
# [+] cls = np.int64(405) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_405_25.pt'
# [+] cls = np.int64(406) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_406_25.pt'
# [+] cls = np.int64(407) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_407_25.pt'
# [+] cls = np.int64(408) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_408_25.pt'
# [+] cls = np.int64(409) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_409_25.pt'
# [+] cls = np.int64(410) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_410_25.pt'
# [+] cls = np.int64(411) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_411_25.pt'
# [+] cls = np.int64(412) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_412_25.pt'
# [+] cls = np.int64(413) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_413_25.pt'
# [+] cls = np.int64(414) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_414_25.pt'
# [+] cls = np.int64(415) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_415_25.pt'
# [+] cls = np.int64(416) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_416_25.pt'
# [+] cls = np.int64(417) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_417_25.pt'
# [+] cls = np.int64(418) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_418_25.pt'
# [+] cls = np.int64(419) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_419_25.pt'
# [+] cls = np.int64(420) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_420_25.pt'
# [+] cls = np.int64(421) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_421_25.pt'
# [+] cls = np.int64(422) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_422_25.pt'
# [+] cls = np.int64(423) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_423_25.pt'
# [+] cls = np.int64(424) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_424_25.pt'
# [+] cls = np.int64(425) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_425_25.pt'
# [+] cls = np.int64(426) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_426_25.pt'
# [+] cls = np.int64(427) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_427_25.pt'
# [+] cls = np.int64(428) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_428_25.pt'
# [+] cls = np.int64(429) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_429_25.pt'
# [+] cls = np.int64(430) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_430_25.pt'
# [+] cls = np.int64(431) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_431_25.pt'
# [+] cls = np.int64(432) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_432_25.pt'
# [+] cls = np.int64(433) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_433_25.pt'
# [+] cls = np.int64(434) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_434_25.pt'
# [+] cls = np.int64(435) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_435_25.pt'
# [+] cls = np.int64(436) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_436_25.pt'
# [+] cls = np.int64(437) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_437_25.pt'
# [+] cls = np.int64(438) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_438_25.pt'
# [+] cls = np.int64(439) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_439_25.pt'
# [+] cls = np.int64(440) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_440_25.pt'
# [+] cls = np.int64(441) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_441_25.pt'
# [+] cls = np.int64(442) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_442_25.pt'
# [+] cls = np.int64(443) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_443_25.pt'
# [+] cls = np.int64(444) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_444_25.pt'
# [+] cls = np.int64(445) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_445_25.pt'
# [+] cls = np.int64(446) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_446_25.pt'
# [+] cls = np.int64(447) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_447_25.pt'
# [+] cls = np.int64(448) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_448_25.pt'
# [+] cls = np.int64(449) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_449_25.pt'
# [+] cls = np.int64(450) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_450_25.pt'
# [+] cls = np.int64(451) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_451_25.pt'
# [+] cls = np.int64(452) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_452_25.pt'
# [+] cls = np.int64(453) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_453_25.pt'
# [+] cls = np.int64(454) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_454_25.pt'
# [+] cls = np.int64(455) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_455_25.pt'
# [+] cls = np.int64(456) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_456_25.pt'
# [+] cls = np.int64(457) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_457_25.pt'
# [+] cls = np.int64(458) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_458_25.pt'
# ...
# [+] cls = np.int64(886) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_886_25.pt'
# [+] cls = np.int64(887) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_887_25.pt'
# [+] cls = np.int64(888) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_888_25.pt'
# [+] cls = np.int64(889) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_889_25.pt'
# [+] cls = np.int64(890) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_890_25.pt'
# [+] cls = np.int64(891) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_891_25.pt'
# [+] cls = np.int64(892) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_892_25.pt'
# [+] cls = np.int64(893) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_893_25.pt'
# [+] cls = np.int64(894) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_894_25.pt'
# [+] cls = np.int64(895) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_895_25.pt'
# [+] cls = np.int64(896) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_896_25.pt'
# [+] cls = np.int64(897) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_897_25.pt'
# [+] cls = np.int64(898) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_898_25.pt'
# [+] cls = np.int64(899) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_899_25.pt'
# [+] cls = np.int64(900) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_900_25.pt'
# [+] cls = np.int64(901) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_901_25.pt'
# [+] cls = np.int64(902) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_902_25.pt'
# [+] cls = np.int64(903) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_903_25.pt'
# [+] cls = np.int64(904) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_904_25.pt'
# [+] cls = np.int64(905) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_905_25.pt'
# [+] cls = np.int64(906) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_906_25.pt'
# [+] cls = np.int64(907) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_907_25.pt'
# [+] cls = np.int64(908) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_908_25.pt'
# [+] cls = np.int64(909) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_909_25.pt'
# [+] cls = np.int64(910) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_910_25.pt'
# [+] cls = np.int64(911) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_911_25.pt'
# [+] cls = np.int64(912) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_912_25.pt'
# [+] cls = np.int64(913) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_913_25.pt'
# [+] cls = np.int64(914) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_914_25.pt'
# [+] cls = np.int64(915) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_915_25.pt'
# [+] cls = np.int64(916) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_916_25.pt'
# [+] cls = np.int64(917) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_917_25.pt'
# [+] cls = np.int64(918) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_918_25.pt'
# [+] cls = np.int64(919) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_919_25.pt'
# [+] cls = np.int64(920) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_920_25.pt'
# [+] cls = np.int64(921) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_921_25.pt'
# [+] cls = np.int64(922) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_922_25.pt'
# [+] cls = np.int64(923) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_923_25.pt'
# [+] cls = np.int64(924) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_924_25.pt'
# [+] cls = np.int64(925) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_925_25.pt'
# [+] cls = np.int64(926) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_926_25.pt'
# [+] cls = np.int64(927) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_927_25.pt'
# [+] cls = np.int64(928) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_928_25.pt'
# [+] cls = np.int64(929) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_929_25.pt'
# [+] cls = np.int64(930) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_930_25.pt'
# [+] cls = np.int64(931) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_931_25.pt'
# [+] cls = np.int64(932) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_932_25.pt'
# [+] cls = np.int64(933) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_933_25.pt'
# [+] cls = np.int64(934) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_934_25.pt'
# [+] cls = np.int64(935) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_935_25.pt'
# [+] cls = np.int64(936) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_936_25.pt'
# [+] cls = np.int64(937) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_937_25.pt'
# [+] cls = np.int64(938) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_938_25.pt'
# [+] cls = np.int64(939) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_939_25.pt'
# [+] cls = np.int64(940) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_940_25.pt'
# [+] cls = np.int64(941) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_941_25.pt'
# [+] cls = np.int64(942) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_942_25.pt'
# [+] cls = np.int64(943) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_943_25.pt'
# [+] cls = np.int64(944) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_944_25.pt'
# [+] cls = np.int64(945) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_945_25.pt'
# [+] cls = np.int64(946) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_946_25.pt'
# [+] cls = np.int64(947) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_947_25.pt'
# [+] cls = np.int64(948) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_948_25.pt'
# [+] cls = np.int64(949) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_949_25.pt'
# [+] cls = np.int64(950) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_950_25.pt'
# [+] cls = np.int64(951) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_951_25.pt'
# [+] cls = np.int64(952) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_952_25.pt'
# [+] cls = np.int64(953) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_953_25.pt'
# [+] cls = np.int64(954) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_954_25.pt'
# [+] cls = np.int64(955) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_955_25.pt'
# [+] cls = np.int64(956) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_956_25.pt'
# [+] cls = np.int64(957) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_957_25.pt'
# [+] cls = np.int64(958) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_958_25.pt'
# [+] cls = np.int64(959) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_959_25.pt'
# [+] cls = np.int64(960) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_960_25.pt'
# [+] cls = np.int64(961) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_961_25.pt'
# [+] cls = np.int64(962) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_962_25.pt'
# [+] cls = np.int64(963) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_963_25.pt'
# [+] cls = np.int64(964) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_964_25.pt'
# [+] cls = np.int64(965) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_965_25.pt'
# [+] cls = np.int64(966) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_966_25.pt'
# [+] cls = np.int64(967) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_967_25.pt'
# [+] cls = np.int64(968) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_968_25.pt'
# [+] cls = np.int64(969) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_969_25.pt'
# [+] cls = np.int64(970) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_970_25.pt'
# [+] cls = np.int64(971) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_971_25.pt'
# [+] cls = np.int64(972) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_972_25.pt'
# [+] cls = np.int64(973) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_973_25.pt'
# [+] cls = np.int64(974) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_974_25.pt'
# [+] cls = np.int64(975) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_975_25.pt'
# [+] cls = np.int64(976) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_976_25.pt'
# [+] cls = np.int64(977) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_977_25.pt'
# [+] cls = np.int64(978) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_978_25.pt'
# [+] cls = np.int64(979) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_979_25.pt'
# [+] cls = np.int64(980) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_980_25.pt'
# [+] cls = np.int64(981) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_981_25.pt'
# [+] cls = np.int64(982) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_982_25.pt'
# [+] cls = np.int64(983) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_983_25.pt'
# [+] cls = np.int64(984) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_984_25.pt'
# [+] cls = np.int64(985) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_985_25.pt'
# [+] cls = np.int64(986) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_986_25.pt'
# [+] cls = np.int64(987) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_987_25.pt'
# [+] cls = np.int64(988) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_988_25.pt'
# [+] cls = np.int64(989) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_989_25.pt'
# [+] cls = np.int64(990) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_990_25.pt'
# [+] cls = np.int64(991) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_991_25.pt'
# [+] cls = np.int64(992) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_992_25.pt'
# [+] cls = np.int64(993) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_993_25.pt'
# [+] cls = np.int64(994) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_994_25.pt'
# [+] cls = np.int64(995) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_995_25.pt'
# [+] cls = np.int64(996) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_996_25.pt'
# [+] cls = np.int64(997) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_997_25.pt'
# [+] cls = np.int64(998) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_998_25.pt'
# [+] cls = np.int64(999) paths[cls] = './models/ResNet50_pretrained/class_impressions/fc_class_999_25.pt'
# {np.int64(0): './models/ResNet50_pretrained/class_impressions/fc_class_0_25.pt', np.int64(1): './models/ResNet50_pretrained/class_impressions/fc_class_1_25.pt', np.int64(2): './models/ResNet50_pretrained/class_impressions/fc_class_2_25.pt', np.int64(3): './models/ResNet50_pretrained/class_impressions/fc_class_3_25.pt', np.int64(4): './models/ResNet50_pretrained/class_impressions/fc_class_4_25.pt', np.int64(5): './models/ResNet50_pretrained/class_impressions/fc_class_5_25.pt', np.int64(6): './models/ResNet50_pretrained/class_impressions/fc_class_6_25.pt', np.int64(7): './models/ResNet50_pretrained/class_impressions/fc_class_7_25.pt', np.int64(8): './models/ResNet50_pretrained/class_impressions/fc_class_8_25.pt', np.int64(9): './models/ResNet50_pretrained/class_impressions/fc_class_9_25.pt', np.int64(10): './models/ResNet50_pretrained/class_impressions/fc_class_10_25.pt', np.int64(11): './models/ResNet50_pretrained/class_impressions/fc_class_11_25.pt', np.int64(12): './models/ResNet50_pretrained/class_impressions/fc_class_12_25.pt', np.int64(13): './models/ResNet50_pretrained/class_impressions/fc_class_13_25.pt', np.int64(14): './models/ResNet50_pretrained/class_impressions/fc_class_14_25.pt', np.int64(15): './models/ResNet50_pretrained/class_impressions/fc_class_15_25.pt', np.int64(16): './models/ResNet50_pretrained/class_impressions/fc_class_16_25.pt', np.int64(17): './models/ResNet50_pretrained/class_impressions/fc_class_17_25.pt', np.int64(18): './models/ResNet50_pretrained/class_impressions/fc_class_18_25.pt', np.int64(19): './models/ResNet50_pretrained/class_impressions/fc_class_19_25.pt', np.int64(20): './models/ResNet50_pretrained/class_impressions/fc_class_20_25.pt', np.int64(21): './models/ResNet50_pretrained/class_impressions/fc_class_21_25.pt', np.int64(22): './models/ResNet50_pretrained/class_impressions/fc_class_22_25.pt', np.int64(23): './models/ResNet50_pretrained/class_impressions/fc_class_23_25.pt', np.int64(24): './models/ResNet50_pretrained/class_impressions/fc_class_24_25.pt', np.int64(25): './models/ResNet50_pretrained/class_impressions/fc_class_25_25.pt', np.int64(26): './models/ResNet50_pretrained/class_impressions/fc_class_26_25.pt', np.int64(27): './models/ResNet50_pretrained/class_impressions/fc_class_27_25.pt', np.int64(28): './models/ResNet50_pretrained/class_impressions/fc_class_28_25.pt', np.int64(29): './models/ResNet50_pretrained/class_impressions/fc_class_29_25.pt', np.int64(30): './models/ResNet50_pretrained/class_impressions/fc_class_30_25.pt', np.int64(31): './models/ResNet50_pretrained/class_impressions/fc_class_31_25.pt', np.int64(32): './models/ResNet50_pretrained/class_impressions/fc_class_32_25.pt', np.int64(33): './models/ResNet50_pretrained/class_impressions/fc_class_33_25.pt', np.int64(34): './models/ResNet50_pretrained/class_impressions/fc_class_34_25.pt', np.int64(35): './models/ResNet50_pretrained/class_impressions/fc_class_35_25.pt', np.int64(36): './models/ResNet50_pretrained/class_impressions/fc_class_36_25.pt', np.int64(37): './models/ResNet50_pretrained/class_impressions/fc_class_37_25.pt', np.int64(38): './models/ResNet50_pretrained/class_impressions/fc_class_38_25.pt', np.int64(39): './models/ResNet50_pretrained/class_impressions/fc_class_39_25.pt', np.int64(40): './models/ResNet50_pretrained/class_impressions/fc_class_40_25.pt', np.int64(41): './models/ResNet50_pretrained/class_impressions/fc_class_41_25.pt', np.int64(42): './models/ResNet50_pretrained/class_impressions/fc_class_42_25.pt', np.int64(43): './models/ResNet50_pretrained/class_impressions/fc_class_43_25.pt', np.int64(44): './models/ResNet50_pretrained/class_impressions/fc_class_44_25.pt', np.int64(45): './models/ResNet50_pretrained/class_impressions/fc_class_45_25.pt', np.int64(46): './models/ResNet50_pretrained/class_impressions/fc_class_46_25.pt', np.int64(47): './models/ResNet50_pretrained/class_impressions/fc_class_47_25.pt', np.int64(48): './models/ResNet50_pretrained/class_impressions/fc_class_48_25.pt', n ...

# %%
def get_class_impression_paths(directory, layer_name, num_samples):
    imp_folder = f'{directory}/class_impressions/'
    paths_ = os.listdir(imp_folder)
    paths = {}
    for p in paths_:
        k = p.split('_')
        cls = int(k[-2])
        num_samp = int(k[-1].split('.')[0])
        layer = k[0]
        if num_samp == num_samples and layer == layer_name:
            paths[cls] = f'{imp_folder}{p}'
    return paths
    

directory = f'./models/{net_name}_{version_name}'
layer_name = first_responsive_layer
num_samples = NUM_SAMPLES
paths = get_class_impression_paths(directory, layer_name, num_samples)
print(paths[0] , len(paths))
# Out:
# ./models/ResNet50_pretrained/class_impressions/fc_class_0_25.pt 1000

# %%
def get_datasets_from_paths(paths, target_classes, labels = labels):
    retain_impressions = []
    retain_y = []
    forget_impressions = []
    forget_y = []
    for cls in list(labels):
        repeated_cls = torch.ones(NUM_SAMPLES , dtype = torch.long , device = device) * cls
        cls_impressions = torch.load(paths[cls]).to(device)
        if cls in target_classes:
            forget_impressions.append(cls_impressions)
            forget_y.append(repeated_cls)
        else :
            retain_impressions.append(cls_impressions)
            retain_y.append(repeated_cls)
            
    X_forget = torch.cat(forget_impressions)
    X_retain = torch.cat(retain_impressions)
    y_forget = torch.cat(forget_y)
    y_retain = torch.cat(retain_y)

    return X_forget, y_forget, X_retain, y_retain

## randomly handpicked classes
target_classes = {10,20,30,39,44,56,111,124, 
                  211,222,267,263,
                    313,334,375,396,
                    424,425,456,477,
                    525,546,557,568,
                    616,637,668,699,
                    717,728,749,780,
                    828,849,870,891,
                    929, 935, 976, 988
                  }
print(f'{len(target_classes) = }')

X_forget, y_forget, X_retain, y_retain = get_datasets_from_paths(paths , target_classes)
print(f'{X_forget.shape = }\t{y_forget.shape = }')
print(f'{X_retain.shape = }\t{y_retain.shape = }')
# Out:
# len(target_classes) = 40
# X_forget.shape = torch.Size([1000, 2048])	y_forget.shape = torch.Size([1000])
# X_retain.shape = torch.Size([24000, 2048])	y_retain.shape = torch.Size([24000])

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu' 
from tqdm import tqdm

class ZeroShotUnlearner:
    def __init__(self, model, forget_loader, retain_loader,
                 first_responsive_layer_string,
                 forget_loss_weight=0.9, retain_loss_weight=0.1,
                 lr=1e-4, device='cuda', clip_grad=5.0):
        self.device = device
        self.model = model.to(device)
        self.forget_loader = forget_loader
        self.retain_loader = retain_loader
        self.forget_loss_weight = forget_loss_weight
        self.retain_loss_weight = retain_loss_weight
        self.clip_grad = clip_grad

        self.tail_model = self._get_tail_model(first_responsive_layer_string).to(device)

        self._freeze_before(first_responsive_layer_string)

        self.optimizer = optim.AdamW(self.tail_model.parameters(), lr=lr)
        self.criterion = nn.CrossEntropyLoss(label_smoothing=0.1)


    def _get_tail_model(self, layer_string):
        modules = []
        include = False
        for name, module in self.model.named_modules():
            if name == layer_string:
                include = True
                modules = [module]  
                break
        if not modules:
            raise ValueError(f"[-] No module named '{layer_string}' found.")
        return nn.Sequential(*modules)


    def _freeze_before(self, layer_string):
        freeze = True
        for name, param in self.model.named_parameters():
            if freeze:
                param.requires_grad = False
            if layer_string in name:
                freeze = False
        print(f"[+] Frozen layers before and including: {layer_string}")

    def unlearn(self, epochs=10, verbose = False):
        self.model.eval()
        self.tail_model.train()

        for ep in tqdm(range(epochs) , desc = 'Unlearning'):
            total_f_loss, total_r_loss = 0.0, 0.0

            for x_f, y_f in self.forget_loader:
                x_f, y_f = x_f.to(self.device), y_f.to(self.device)
                out_f = self.tail_model(x_f)
                loss_f = self.criterion(out_f, y_f)

                loss =  self.forget_loss_weight * loss_f

                self.optimizer.zero_grad()
                loss.backward()
                nn.utils.clip_grad_norm_(self.tail_model.parameters(), self.clip_grad)
                self.optimizer.step()

                total_f_loss += loss_f.item()

            for x_r, y_r in self.retain_loader:
                x_r, y_r = x_r.to(self.device), y_r.to(self.device)
                out_r = self.tail_model(x_r)
                loss_r = self.criterion(out_r, y_r)

                loss = - self.retain_loss_weight * loss_r
                
                self.optimizer.zero_grad()
                loss.backward()
                nn.utils.clip_grad_norm_(self.tail_model.parameters(), self.clip_grad)
                self.optimizer.step()

                total_r_loss += loss_r.item()
            if verbose and (ep+1) % 10 == 0:
                print(f"Epoch [{ep+1:5d}/{epochs:5d}] | Forget Loss: {total_f_loss:.6f} | Retain Loss: {total_r_loss:.6f}")

        return self.tail_model

u_model = copy.deepcopy(model)
BATCH_SIZE = 16
X_forget_dataset = torch.utils.data.TensorDataset(X_forget, y_forget)
X_retain_dataset = torch.utils.data.TensorDataset(X_retain, y_retain)
print(f'[>] {len(X_forget_dataset) = }, {len(X_retain_dataset) = }')
print(f'[>] {first_responsive_layer = }')

unlearner = ZeroShotUnlearner(
    u_model, 
    first_responsive_layer_string= first_responsive_layer,
    forget_loader= torch.utils.data.DataLoader(X_forget_dataset, batch_size=BATCH_SIZE, shuffle=True),
    retain_loader= torch.utils.data.DataLoader(X_retain_dataset, batch_size=BATCH_SIZE, shuffle=True),
    lr = 1e-3,
    forget_loss_weight=0.9, 
    retain_loss_weight=0.1,
    device=device,
)   

tail_model = unlearner.unlearn(epochs=1000)
# Out:
# [>] len(X_forget_dataset) = 1000, len(X_retain_dataset) = 24000
# [>] first_responsive_layer = 'fc'
# [+] Frozen layers before and including: fc
# Unlearning: 100%|██████████| 1000/1000 [31:52<00:00,  1.91s/it]

# %%
import json
with open("imagenet_class_index.json") as f:
    idx_to_info = json.load(f)

idx_to_wnid = {int(k): v[0] for k, v in idx_to_info.items()}
idx_to_name = {int(k): v[1] for k, v in idx_to_info.items()}
class_idx_to_name = idx_to_name

# %%
acc_after = classwise_accuracy(u_model, val_loader, device)
plot_accuracy_diff(acc_before, acc_after, class_idx_to_name)
# Out:
# 100%|██████████| 782/782 [01:08<00:00, 11.50it/s]

# %%
import pandas as pd

def accuracy_comparison_table(acc1, acc2, idx_to_name):
    data = []
    for cls in acc1:
        old = acc1[cls]
        new = acc2.get(cls, 0)
        change = new - old
        data.append({
            'Class Index': cls,
            'Class Name': idx_to_name.get(str(cls), f'class_{cls}'),
            'Original Acc': old,
            'Unlearned Acc': new,
            'Δ Accuracy': change
        })
    df = pd.DataFrame(data).sort_values(by='Δ Accuracy')
    return df

table = accuracy_comparison_table(acc_before, acc_after, class_idx_to_name)
table.head(10)
# Out:
#      Class Index Class Name  Original Acc  Unlearned Acc  Δ Accuracy
# 396          396  class_396          94.0            0.0       -94.0
# 10            10   class_10          94.0            0.0       -94.0
# 334          334  class_334          92.0            0.0       -92.0
# 425          425  class_425          92.0            0.0       -92.0
# 263          263  class_263          90.0            0.0       -90.0
# 988          988  class_988          94.0            4.0       -90.0
# 375          375  class_375          90.0            0.0       -90.0
# 39            39   class_39          88.0            0.0       -88.0
# 20            20   class_20          88.0            0.0       -88.0
# 616          616  class_616          88.0            0.0       -88.0

# %%
overall_accuracy_before = sum(acc_before.values()) / len(acc_before)
overall_accuracy_after = sum(acc_after.values()) / len(acc_after)
print(f"Overall Accuracy Before Unlearning: {overall_accuracy_before:.2f}%")
print(f"Overall Accuracy After Unlearning: {overall_accuracy_after:.2f}%")
# Out:
# Overall Accuracy Before Unlearning: 76.14%
# Overall Accuracy After Unlearning: 73.35%

# %%
forget_class_table = table[table['Class Index'].isin(target_classes)]
retain_class_table = table[~table['Class Index'].isin(target_classes)]

avg_unlearned_acc_forget = forget_class_table['Unlearned Acc'].mean()
avg_unlearned_acc_retain = retain_class_table['Unlearned Acc'].mean()

print(f"Average Unlearned Accuracy for Forget Classes: {avg_unlearned_acc_forget:.2f}%")
print(f"Average Unlearned Accuracy for Retain Classes: {avg_unlearned_acc_retain:.2f}%")
# Out:
# Average Unlearned Accuracy for Forget Classes: 1.40%
# Average Unlearned Accuracy for Retain Classes: 76.35%

# %% [markdown]
# # Better Visualizing - Unlearn

# %%
# first 50 classes and middle 390 to 440 and last 50 classes
target_classes = np.concatenate([
    np.arange(0, 50),
    np.arange(390, 440),
    np.arange(950, 1000)
])

target_classes = set(target_classes)
len(target_classes)
# Out:
# 150

# %%
X_forget, y_forget, X_retain, y_retain = get_datasets_from_paths(paths , target_classes)
print(f'{X_forget.shape = }\t{y_forget.shape = }')
print(f'{X_retain.shape = }\t{y_retain.shape = }')
# Out:
# X_forget.shape = torch.Size([3750, 2048])	y_forget.shape = torch.Size([3750])
# X_retain.shape = torch.Size([21250, 2048])	y_retain.shape = torch.Size([21250])

# %%
u_model_v2 = copy.deepcopy(model)
BATCH_SIZE = 16

X_forget_dataset = torch.utils.data.TensorDataset(X_forget, y_forget)
X_retain_dataset = torch.utils.data.TensorDataset(X_retain, y_retain)

print(f'{len(X_forget_dataset) = }, {len(X_retain_dataset) = }')
print(f'{first_responsive_layer = }')
# Out:
# len(X_forget_dataset) = 3750, len(X_retain_dataset) = 21250
# first_responsive_layer = 'fc'

# %%
unlearner = ZeroShotUnlearner(
    u_model_v2, 
    first_responsive_layer_string= first_responsive_layer,
    forget_loader= torch.utils.data.DataLoader(X_forget_dataset, batch_size=BATCH_SIZE, shuffle=True),
    retain_loader= torch.utils.data.DataLoader(X_retain_dataset, batch_size=BATCH_SIZE, shuffle=True),
    lr = 1e-3,
    forget_loss_weight=0.9, 
    retain_loss_weight=0.1,
    device=device,
)   

tail_model = unlearner.unlearn(epochs=100)
# Out:
# [+] Frozen layers before and including: fc
# Unlearning: 100%|██████████| 100/100 [03:04<00:00,  1.85s/it]

# %%
acc_after_v2 = classwise_accuracy(u_model_v2, val_loader, device)
# Out:
# 100%|██████████| 782/782 [01:08<00:00, 11.40it/s]

# %%
plot_accuracy_diff(acc_before, acc_after_v2, class_idx_to_name)

# %%
overall_accuracy_before = sum(acc_before.values()) / len(acc_before)
overall_accuracy_after = sum(acc_after_v2.values()) / len(acc_after_v2)
print(f"Overall Accuracy Before Unlearning: {overall_accuracy_before:.2f}%")
print(f"Overall Accuracy After Unlearning: {overall_accuracy_after:.2f}%")

table = accuracy_comparison_table(acc_before, acc_after_v2, class_idx_to_name)
forget_class_table = table[table['Class Index'].isin(target_classes)]
retain_class_table = table[~table['Class Index'].isin(target_classes)]

avg_unlearned_acc_forget = forget_class_table['Unlearned Acc'].mean()
avg_unlearned_acc_retain = retain_class_table['Unlearned Acc'].mean()

print(f"\nAverage Unlearned Accuracy for Forget Classes: {avg_unlearned_acc_forget:.2f}%")
print(f"Average Unlearned Accuracy for Retain Classes: {avg_unlearned_acc_retain:.2f}%")
# Out:
# Overall Accuracy Before Unlearning: 76.14%
# Overall Accuracy After Unlearning: 65.23%
#
# Average Unlearned Accuracy for Forget Classes: 0.11%
# Average Unlearned Accuracy for Retain Classes: 76.72%

# %%
table.head(10)
# Out:
#      Class Index Class Name  Original Acc  Unlearned Acc  Δ Accuracy
# 986          986  class_986         100.0            0.0      -100.0
# 984          984  class_984         100.0            0.0      -100.0
# 995          995  class_995         100.0            0.0      -100.0
# 392          392  class_392          98.0            0.0       -98.0
# 13            13   class_13          98.0            0.0       -98.0
# 9              9    class_9          98.0            0.0       -98.0
# 19            19   class_19          98.0            0.0       -98.0
# 11            11   class_11          98.0            0.0       -98.0
# 24            24   class_24          98.0            0.0       -98.0
# 955          955  class_955          96.0            0.0       -96.0

# %% [markdown]
# ### Train more epochs ?

# %%
u_model_v3 = copy.deepcopy(model)
BATCH_SIZE = 16

X_forget_dataset = torch.utils.data.TensorDataset(X_forget, y_forget)
X_retain_dataset = torch.utils.data.TensorDataset(X_retain, y_retain)

print(f'{len(X_forget_dataset) = }, {len(X_retain_dataset) = }')
print(f'{first_responsive_layer = }')

unlearner = ZeroShotUnlearner(
    u_model_v3, 
    first_responsive_layer_string= first_responsive_layer,
    forget_loader= torch.utils.data.DataLoader(X_forget_dataset, batch_size=BATCH_SIZE, shuffle=True),
    retain_loader= torch.utils.data.DataLoader(X_retain_dataset, batch_size=BATCH_SIZE, shuffle=True),
    lr = 1e-3,
    forget_loss_weight=0.9, 
    retain_loss_weight=0.1,
    device=device,
)   

tail_model = unlearner.unlearn(epochs=1000)

acc_after_v3 = classwise_accuracy(u_model_v3, val_loader, device)

plot_accuracy_diff(acc_before, acc_after_v3, class_idx_to_name)

overall_accuracy_before = sum(acc_before.values()) / len(acc_before)
overall_accuracy_after = sum(acc_after_v3.values()) / len(acc_after_v3)
print(f"Overall Accuracy Before Unlearning: {overall_accuracy_before:.2f}%")
print(f"Overall Accuracy After Unlearning: {overall_accuracy_after:.2f}%")

table_v3= accuracy_comparison_table(acc_before, acc_after_v3, class_idx_to_name)

table_v3.head(10)

forget_class_table_v3 = table_v3[table_v3['Class Index'].isin(target_classes)]
retain_class_table_v3 = table_v3[~table_v3['Class Index'].isin(target_classes)]

avg_unlearned_acc_forget_v3 = forget_class_table_v3['Unlearned Acc'].mean()
avg_unlearned_acc_retain_v3 = retain_class_table_v3['Unlearned Acc'].mean()

print(f"\nAverage Unlearned Accuracy for Forget Classes: {avg_unlearned_acc_forget_v3:.2f}%")
print(f"Average Unlearned Accuracy for Retain Classes: {avg_unlearned_acc_retain_v3:.2f}%")
# Out:
# len(X_forget_dataset) = 3750, len(X_retain_dataset) = 21250
# first_responsive_layer = 'fc'
# [+] Frozen layers before and including: fc
# Unlearning:   0%|          | 0/1000 [00:00<?, ?it/s]
# Unlearning: 100%|██████████| 1000/1000 [30:47<00:00,  1.85s/it]
# 100%|██████████| 782/782 [01:08<00:00, 11.38it/s]
# Overall Accuracy Before Unlearning: 76.14%
# Overall Accuracy After Unlearning: 65.31%
#      Class Index Class Name  Original Acc  Unlearned Acc  Δ Accuracy
# 995          995  class_995         100.0            0.0      -100.0
# 984          984  class_984         100.0            0.0      -100.0
# 986          986  class_986         100.0            0.0      -100.0
# 392          392  class_392          98.0            0.0       -98.0
# 19            19   class_19          98.0            0.0       -98.0
# 11            11   class_11          98.0            0.0       -98.0
# 13            13   class_13          98.0            0.0       -98.0
# 9              9    class_9          98.0            0.0       -98.0
# 24            24   class_24          98.0            0.0       -98.0
# 953          953  class_953          96.0            0.0       -96.0
# Average Unlearned Accuracy for Forget Classes: 0.01%
# Average Unlearned Accuracy for Retain Classes: 76.83%
